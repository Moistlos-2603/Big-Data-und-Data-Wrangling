# %%
import pandas as pd

# %%
df = pd.read_csv("../datasets/restaurants_L3_dirty.csv")

pd.unique(df["city"]).tolist()

df["city"] = df["city"].apply(lambda x: "los angeles" if x == "la" else x)
df["city"] = df["city"].apply(lambda x: "los angeles" if x == "hollywood" else x)
df["city"] = df["city"].apply(lambda x: "los angeles" if x == "studio city" else x)
df["city"] = df["city"].apply(lambda x: "los angeles" if x == "beverly hills" else x)
df["city"] = df["city"].apply(lambda x: "los angeles" if x == "toluca lake" else x)
df["city"] = df["city"].apply(lambda x: "los angeles" if x == "pacific palisades" else x)
df["city"] = df["city"].apply(lambda x: "los angeles" if x == "sherman oaks" else x)
df["city"] = df["city"].apply(lambda x: "los angeles" if x == "los feliz" else x)


df["city"] = df["city"].apply(lambda x: "new york" if x == "brooklyn" else x)
df["city"] = df["city"].apply(lambda x: "new york" if x == "ny" else x)

df["city"] = df["city"].apply(lambda x: "los angeles" if x == "pacific palisades" else x)



print(pd.unique(df["city"]))
# Out:
# ['los angeles' 'santa monica' 'new york' 'las vegas' 'atlanta'
#  'san francisco']
